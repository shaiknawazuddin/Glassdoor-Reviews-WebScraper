# %% [markdown]
# # Glassdoor Reviews WebScraper

# %% [markdown]
# ### Created by Shaik Nawazuddin

# %% [markdown]
# Importing all the necessary Libraries

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# Specifying User-Agent
#
# Just google 'My user agent' and paste it as the value for key 'User-Agent'

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36'}

# %% [markdown]
# Creating a temporary list to append data of each page into it

# %%
temp = list()

# %% [markdown]
# Specify the last page number

# %%
start_page = 1
print('Please enter the last page number')
end_page = (int(input())) + 1
# Out:
# Please enter the last page number
# 5

# %% [markdown]
# Example:
#
# https://www.glassdoor.co.in/Reviews/Glassdoor-Reviews-E100431.htm
#
# If the link looks like the above, kindly take only the 'https://www.glassdoor.co.in/Reviews/Glassdoor-Reviews-E100431' part as the first_half and I'd recommend not to change the second_half unless there is a specific filtering applied.

# %%
for page in range(start_page, end_page):
    print('Page number is: ', page)

    try:
#Kindly specify the correct URL link in the right format without including the page number as shown in the example        
        first_half = 'https://www.glassdoor.co.in/Reviews/Glassdoor-Reviews-E100431'
        second_half = '.htm?filter.iso3Language=eng'     
        html = requests.get(first_half + '_P' + str(page) + second_half, verify = True, headers = headers)
        html.raise_for_status()
    except requests.exceptions.HTTPError as errh:
        print('HTTP Error: ', errh)
    except requests.exceptions.ConnectionError as errc:
        print('Error Connecting: ', errc)
        time.sleep(30)
    except requests.exceptions.Timeout as errt:
        print('Timeout Error: ', errt)
        time.sleep(30)
    except requests.exceptions.RequestException as err:
        print('Something else: ', err)
   
    bsobj = BeautifulSoup(html.text, 'html.parser')

    reviews = bsobj.find_all(class_='gdReview')
   
    for review in reviews:
        try:
            desc = review.find(class_='reviewLink').get_text()
        except:
            desc = None
        try:
            date_job_title = review.find(class_='authorJobTitle').get_text()
            date_job_title = date_job_title.split('-')
            review_date = date_job_title[0]
            reviewer_job_title = date_job_title[1]
        except:
            review_date = None
            reviewer_job_title = None
        try:
            location = review.find(class_='authorLocation').get_text()
        except:
            location = None
        try:
            rate = review.find(class_='ratingNumber').get_text()
        except:
            rate = None
        try:
            state = review.find(class_='pt-xsm').get_text()
        except:
            state_exp = None
        try:
            pros =review.select('span[data-test="pros"]')[0].text
            pros = pros.replace('\t', '')
            pros = pros.replace('\r', ' ')
            pros = pros.replace('\n', ' ')
        except:
            pros = None
        try:
            cons = review.select('span[data-test="cons"]')[0].text
            cons = cons.replace('\t', '')
            cons = cons.replace('\r', ' ')
            cons = cons.replace('\n', ' ')
        except:
            cons = None
       
        data = {
                'Title': desc,
                'Date': review_date,
                'Job Title': reviewer_job_title,
                'Location' : location,
                'Rating': rate,
                'State and Experience': state,
                'Pros' : pros,
                'Cons': cons
            }
        temp.append(data)
# Out:
# Page number is:  1
# Page number is:  2
# Page number is:  3
# Page number is:  4
# Page number is:  5

# %% [markdown]
# Loading the temp data into a DataFrame

# %%
df_temp = pd.DataFrame(temp)
try:
    df_temp[['State of Reviewer', 'Experience']] = df_temp['State and Experience'].str.split(', ', expand = True)
except:
    df_temp['State of Reviewer'] = df_temp['State and Experience']
    df_temp['Experience'] = ''
df = df_temp[['Title', 'Date', 'Job Title', 'Location', 'Rating', 'State of Reviewer', 'Experience', 'Pros', 'Cons']]
df
# Out:
#                                                 Title           Date  \
# 0                  Glassdoor leads with transparency!  Jul 12, 2022
# 1                                       Great company  Jul 19, 2022
# 2     Very good company, many opportunities available  May 25, 2021
# 3                               Crazy amazing people.  Jan 15, 2018
# 4                     Wonderful Internship experience  Mar 26, 2017
# 26                 Enterprise Account Manager               None    5.0
# 27                                    Analyst               None    4.0
# 28                                        SDR               None    3.0
# 29                       Lead Product Manager  San Francisco, CA    5.0
# 30                   National Account Manager    London, England    4.0
# 31                         Anonymous Employee               None    5.0
# 32                   Customer Success Manager    London, England    5.0
# 33                         Anonymous Employee               None    4.0
# 34                          Event Coordinator  San Francisco, CA    4.0
# 35                                   Designer    San Antonio, TX    5.0
# 36                                  VP Design               None    5.0
# 37                          Account Executive        Chicago, IL    3.0
# 38                           Customer Success               None    4.0
# 39                   Senior Account Executive  San Francisco, CA    4.0
# 40                   Senior Software Engineer               None    5.0
# 41                       Sales Representative               None    4.0
# 42                           Sales Operations               None    4.0
# 43                         Anonymous Employee               None    4.0
# 44                         Anonymous Employee               None    5.0
# 45                   Senior Account Executive               None    3.0
# 46           Senior Product Marketing Manager    Los Angeles, CA    5.0
# 47                         Anonymous Employee               None    5.0
# 48                         People Coordinator  San Francisco, CA    4.0
# 49                    Talent Acquisition Lead               None    5.0
#
#    State of Reviewer          Experience  \
# 0   Current Employee   more than 3 years
# 1   Current Employee                None
# 2   Current Employee                None
# 3   Current Employee                None
# 4    Former Employee                None
# 5   Current Employee    less than 1 year
# 6   Current Employee    less than 1 year
# 7   Current Employee                None
# 8   Current Employee    more than 1 year
# 9   Current Employee                None
# 10  Current Employee   more than 3 years
# 11   Former Employee    less than 1 year
# 12  Current Employee                None
# 13  Current Employee    less than 1 year
# 14   Former Employee   more than 3 years
# 15  Current Employee   more than 3 years
# 16  Current Employee                None
# 17  Current Employee    less than 1 year
# 18  Current Employee    more than 1 year
# 19  Current Employee  more than 10 years
# 20  Current Employee    more than 1 year
# 21  Current Employee    less than 1 year
# 22  Current Employee    less than 1 year
# 23   Former Employee    more than 1 year
# 24  Current Employee    more than 1 year
# 25   Former Employee    more than 1 year
# 26  Current Employee    more than 1 year
# 27  Current Employee   more than 3 years
# 28   Former Employee                None
# 29   Former Employee    more than 1 year
# 30  Current Employee   more than 5 years
# 31  Current Employee    less than 1 year
# 32  Current Employee    less than 1 year
# 33  Current Employee    less than 1 year
# 34   Former Employee    more than 1 year
# 35  Current Employee    less than 1 year
# 36  Current Employee                None
# 37  Current Employee                None
# 38  Current Employee                None
# 39   Former Employee    more than 1 year
# 40  Current Employee    more than 1 year
# 41  Current Employee                None
# 42  Current Employee                None
# 43  Current Employee   more than 3 years
# 44   Former Employee    more than 1 year
# 45   Former Employee    more than 1 year
# 46  Current Employee    less than 1 year
# 47  Current Employee    more than 1 year
# 48   Former Employee    less than 1 year
# 49  Current Employee    less than 1 year
#
#                                                  Pros  \
# 0   - I genuinely enjoy my day-to-day job & cowork...
# 1   You can build a good network here that always ...
# 2   Good company, friendly , great exposure, happy...
# 3   Now for an organisation running the show ,it i...
# 4   Open organization flexible timings. Company ta...
# 5   The people here are everything; I've never met...
# 6   I love working here, it's the best job I've ha...
# 7         Everyone is really bought into the mission.
# 8   Glassdoor is one of the best companies I have ...
# 9   I miss the days working at the Mill Valley off...
# 10  We are building toward a really compelling and...
# 11            Great Support and growth opportunities.
# 12  They care about you as a person, unlimited PTO...
# 13  Glassdoor uses the latest technology stack (Sp...
# 14  It was a worthwhile place to work the first tw...
# 15  - I genuinely enjoy my day-to-day job & cowork...
# 16  The culture! Love love love the culture and th...
# 17  Everyone I work with has been very welcoming a...
# 18  There is no doubt that this is a company that ...
# 19  If you're looking for a company that cares abo...
# 20  I really like working at Glassdoor and I appre...
# 21  Glassdoor walks the walk! The company follows ...
# 22  Glassdoor has an excellent culture. They are b...
# 23  - Strives to live up to it's values of transpa...
# 24  Excellent pay and benefits package Very pro-we...
# 25  Great environment, Wonderful team, Amazing pro...
# 26  A great company to grow and achieve the goals ...
# 27  Manager is very supportive and accessible; act...
# 28             Good people to work with, easy to sell
# 29  Good culture and work life balance. Plenty of ...
# 30  We are in growth mode again here in EMEA! Than...
# 31  Glassdoor walks the talk, period. For the firs...
# 32  I’ve been working at Glassdoor for just under ...
# 33  Good people. Good salary. Good benefits. Flexi...
# 34  -great employee benefits like catered lunches,...
# 35  Very diversity. And everyone here has the same...
# 36  Great company that is living it's values and m...
# 37                   Great People and had good tools.
# 38  I love it here. Been here for a few years and ...
# 39  Culture - worked with some of the greatest peo...
# 40  - Extremely transparent company with solid eth...
# 41  Great company that truly cares about employee ...
# 42                 Great culture, flexible WFH policy
# 43  Comp & Benefits Work/Life Balance Diversity & ...
# 44  Great group of professionals. Everyone made it...
# 45  A lot of talented people that shared a passion...
# 46  -An overarching sense of altruism throughout v...
# 47  Hardworking and very kind coworkers. Also we h...
# 48  Benefits, work-life balance, fun events, more ...
# 49  Positive & supportive work culture, emphasis o...
#
#                                                  Cons
# 0   - There can be delays due to internal system e...
# 1                              Nothing i can think of
# 2                             No cons to be specified
# 3                You don't wanna learn , not for you.
# 4                   None as such everyone enjoys here
# 5   You have to wear a lot of hats in this role. T...
# 6   People are very focused on their work here so ...
# 7   Comp and pay are a bit on the lower end of the...
# 8   But in regards to overall sales experience, I ...
# 9         not data driven; hard to grow a career here
# 10  We are experiencing a lot of attrition, so res...
# 11                              Not a lot of benefits
# 12                       None really. It’s been great
# 13  The location is remote. I would love to visit ...
# 14  n.b. In keeping with Glassdoor's Community Gui...
# 15  - There can be delays due to internal system e...
# 16  Days can be very long and the workload very dr...
# 17              None yet, although I've just started.
# 18  I can honestly and truthfully say, there is no...
# 19  While I've had an amazing experience at Glassd...
# 20  Previously zip-tiered salary was very poorly i...
# 21  Some growing pains with the partnership with I...
# 22  None that I can honestly think of. I am very h...
# 23  - terrible leadership mostly at the C and VP l...
# 24  Can at times have slight delays in doing day-t...
# 25           Nothing that they now haven't addressed.
# 26           Like any Saas company changes are often.
# 27  Growing pains associated with new corporate st...
# 28  Laid me off. Dont hire then lay people off rig...
# 29  Low total compensation compared to other tech ...
# 30  - Partnership with Indeed is still a struggle,...
# 31  The interview process is lengthier and more co...
# 32  None that I’d say warrant not wanting to work ...
# 33                      To be updated when I find any
# 34  -relatively low salary/bonuses compared to oth...
# 35       Didn't notice any major cons at this moment.
# 36                      None so far...so far so good.
# 37  Was let go after Covid after being told compan...
# 38  Attrition. Top talent is leaving, which may be...
# 39  C-Suite- after the merger, they changed strate...
# 40  - Benefits could be slightly better (better 40...
# 41  Lots of changes with Indeed partnership and le...
# 42         Sometimes growth trajectory may be unclear
# 43  Indeed Partnership Frequent Account Transition...
# 44  There is constant change, often for the sake o...
# 45  Direction of the company and long-term strateg...
# 46  -B2C Product needs to modernize to win conside...
# 47  Could get busy at times but that happens at an...
# 48  Leadership only pretends to be transparent and...
# 49  No company is perfect, but I'm hard pressed to...

# %% [markdown]
# Exporting the DataFrame to an excel file

# %%
df.to_excel('Glassdoor Reviews.xlsx', index = False)
